# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/iris.csv")
df # This data frame contains both numerical and descriptive information. We want to extract the numerical data.
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
df_num = df.select_dtypes(exclude = "object")#first we calculate some statistical measures

# %%
df_num.mean()
# Out:
# Unnamed: 0      75.500000
# Sepal.Length     5.843333
# Sepal.Width      3.057333
# Petal.Length     3.758000
# Petal.Width      1.199333
# dtype: float64

# %%
df_num.median()
# Out:
# Unnamed: 0      75.50
# Sepal.Length     5.80
# Sepal.Width      3.00
# Petal.Length     4.35
# Petal.Width      1.30
# dtype: float64

# %%
df_num.mode()
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0             1           5.0          3.0           1.4          0.2
# 1             2           NaN          NaN           1.5          NaN
# 2             3           NaN          NaN           NaN          NaN
# 3             4           NaN          NaN           NaN          NaN
# 4             5           NaN          NaN           NaN          NaN
# ..          ...           ...          ...           ...          ...
# 145         146           NaN          NaN           NaN          NaN
# 146         147           NaN          NaN           NaN          NaN
# 147         148           NaN          NaN           NaN          NaN
# 148         149           NaN          NaN           NaN          NaN
# 149         150           NaN          NaN           NaN          NaN
#
# [150 rows x 5 columns]

# %%
df_num.kurt()
# Out:
# Unnamed: 0     -1.200000
# Sepal.Length   -0.552064
# Sepal.Width     0.228249
# Petal.Length   -1.402103
# Petal.Width    -1.340604
# dtype: float64

# %%
df_num.skew()
# Out:
# Unnamed: 0      0.000000
# Sepal.Length    0.314911
# Sepal.Width     0.318966
# Petal.Length   -0.274884
# Petal.Width    -0.102967
# dtype: float64

# %%
df_num.corr()
# Out:
#               Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Unnamed: 0      1.000000      0.716676    -0.402301      0.882637     0.900027
# Sepal.Length    0.716676      1.000000    -0.117570      0.871754     0.817941
# Sepal.Width    -0.402301     -0.117570     1.000000     -0.428440    -0.366126
# Petal.Length    0.882637      0.871754    -0.428440      1.000000     0.962865
# Petal.Width     0.900027      0.817941    -0.366126      0.962865     1.000000

# %%
df_num.std()
# Out:
# Unnamed: 0      43.445368
# Sepal.Length     0.828066
# Sepal.Width      0.435866
# Petal.Length     1.765298
# Petal.Width      0.762238
# dtype: float64

# %%
plt.plot(df_num["Sepal.Length"]) # now, some plots
plt.ylabel("Sepal Length")
# Out:
# Text(0, 0.5, 'Sepal Length')

# %%
plt.plot(df_num["Sepal.Width"])
plt.ylabel("Sepal Width")
# Out:
# Text(0, 0.5, 'Sepal Width')

# %%
plt.plot(df_num["Petal.Length"])
plt.ylabel("Petal Length")
# Out:
# Text(0, 0.5, 'Petal Length')

# %%
plt.plot(df_num["Sepal.Width"])
plt.ylabel("Sepal Width")
# Out:
# Text(0, 0.5, 'Sepal Width')

# %%
plt.scatter(df_num["Sepal.Length"], df_num["Petal.Length"])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
# Out:
# Text(0, 0.5, 'Petal.Length')

# %%
plt.scatter(df_num["Sepal.Length"], df_num["Sepal.Width"])
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
# Out:
# Text(0, 0.5, 'Sepal Width')

# %%
plt.scatter(df_num["Petal.Length"], df_num["Petal.Width"])
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
# Out:
# Text(0, 0.5, 'Petal Width')

# %%
plt.boxplot(df_num["Sepal.Length"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d3a49add150>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d3a49adf070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d3a49e11570>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d3a49adf5b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d3a49adf850>],
#  'means': []}

# %%
plt.boxplot(df_num["Sepal.Width"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d3a49b1ed10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d3a49b1f250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d3a49b1ea70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d3a49b1f790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d3a49b1fa30>],
#  'means': []}

# %%
plt.boxplot(df_num["Petal.Length"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d3a49c59900>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d3a49c59e40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d3a49c59660>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d3a49c5a380>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d3a49b1cc10>],
#  'means': []}

# %%
plt.boxplot(df_num["Petal.Width"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d3a4a157190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d3a4a156320>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d3a4a155ed0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d3a4a155540>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d3a4a1560e0>],
#  'means': []}

# %%
plt.hist(df_num["Sepal.Length"])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_num["Sepal.Width"])
# Out:
# (array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_num["Petal.Length"])
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_num["Petal.Width"])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)
